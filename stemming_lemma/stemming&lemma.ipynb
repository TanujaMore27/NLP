# %% [markdown]
# Stemming in NLTK

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
  print(word ," | ",stemmer.stem(word))
# Out:
# eating  |  eat
# eats  |  eat
# eat  |  eat
# ate  |  ate
# adjustable  |  adjust
# rafting  |  raft
# ability  |  abil
# meeting  |  meet

# %% [markdown]
# Lemmatization in Spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
docs = nlp("Mando talked for 3 hours although talking isn't his thing")
doc = nlp("eating eats eat ate adjustable rafting ability meeting better")
for i in docs:
  print(i," | ",i.lemma_)
# Out:
# Mando  |  Mando
# talked  |  talk
# for  |  for
# 3  |  3
# hours  |  hour
# although  |  although
# talking  |  talk
# is  |  be
# n't  |  not
# his  |  his
# thing  |  thing

# %% [markdown]
# Customizing lemmatizer

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ar = nlp.get_pipe('attribute_ruler')
ar.add([[{'TEXT':'Bro'}],[{'TEXT':'Brah'}]],{'LEMMA':'Brother'})
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")

for token in doc:
  print(token," | ",token.lemma_)
# Out:
# Bro  |  Brother
# ,  |  ,
# you  |  you
# wanna  |  wanna
# go  |  go
# ?  |  ?
# Brah  |  Brother
# ,  |  ,
# do  |  do
# n't  |  not
# say  |  say
# no  |  no
# !  |  !
# I  |  I
# am  |  be
# exhausted  |  exhaust

# %%
doc[0]
# Out:
# Bro

# %%
doc[6].lemma_
# Out:
# 'Brother'
