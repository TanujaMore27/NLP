# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('movies_sentiment_data.csv')

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['category'] = df['sentiment'].apply(lambda x:1 if x=='positive' else 0)

# %%
df.head()
# Out:
#                                               review sentiment  category
# 0  One of the other reviewers has mentioned that ...  positive         1
# 1  A wonderful little production. <br /><br />The...  positive         1
# 2  I thought this was a wonderful way to spend ti...  positive         1
# 3  Basically there's a family where a little boy ...  negative         0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive         1

# %%
df['category'].value_counts()
# Out:
# category
# 1    25000
# 0    25000
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(df.review,df.category,test_size=0.2,random_state=20)

# %% [markdown]
# #### Exercise-1
#
# 1.the movie review's positive or negative..
# Note:
# * use CountVectorizer for pre-processing the text.
# * use Multinomial Naive Bayes as the classifier.
# * print the classification report.

# %%
clf = Pipeline([
    ('vectorizer',CountVectorizer()),
    ('nb',MultinomialNB())
])

# %%
clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      5071
#            1       0.87      0.82      0.84      4929
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %% [markdown]
# #### Exercise-2
# using sklearn pipeline module create a classification pipeline to classify the movie review's positive or negative.
# Note:
# * use Random Forest as the classifier with estimators as 50 and criterion as entropy.

# %%
clf2 = Pipeline([
    ('vectorizer2',CountVectorizer()),
    ('rf',RandomForestClassifier())
])

# %%
clf2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer2', CountVectorizer()),
#                 ('rf', RandomForestClassifier())])

# %%
y_pred = clf2.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85      5071
#            1       0.85      0.86      0.85      4929
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %% [markdown]
# #### Exercise-3
# using sklearn pipeline module create a classification pipeline to classify the movie review's positive or negative..
# Note:
# * use CountVectorizer for pre-processing the text.
# * use KNN as the classifier with n_neighbors of 10 and metric as 'euclidean'.
# * print the classification report.

# %%
clf3 = Pipeline([
    ('vectorizer3',CountVectorizer()),
    ('knn',KNeighborsClassifier(n_neighbors=10))
])

# %%
clf3.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer3', CountVectorizer()),
#                 ('knn', KNeighborsClassifier(n_neighbors=10))])

# %%
y_pred = clf3.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66      5071
#            1       0.65      0.66      0.66      4929
#
#     accuracy                           0.66     10000
#    macro avg       0.66      0.66      0.66     10000
# weighted avg       0.66      0.66      0.66     10000
